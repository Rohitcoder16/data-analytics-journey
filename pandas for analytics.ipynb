# %%
import pandas as pd 
data1={"Eid":["E01", "E02", "E03", "E04", "E05", "E06"],
       "Name":["Rohit", "Rahul", "Sahil", "Bhushan", "Abhijit", "Viraj"]}
data2={"Eid":["E01", "E02", "E03", "E04", "E05", "E06"],
       "Salary":[200000,100000,150000,45000,100000,160000]}

df1= pd.DataFrame(data1)
df2= pd.DataFrame(data2)
print(df1)
print()
print(df2)
# Out:
#    Eid     Name
# 0  E01    Rohit
# 1  E02    Rahul
# 2  E03    Sahil
# 3  E04  Bhushan
# 4  E05  Abhijit
# 5  E06    Viraj
#
#    Eid  Salary
# 0  E01  200000
# 1  E02  100000
# 2  E03  150000
# 3  E04   45000
# 4  E05  100000
# 5  E06  160000

# %%
print(pd.merge(df1,df2,on = "Eid"))
# Out:
#    Eid     Name  Salary
# 0  E01    Rohit  200000
# 1  E02    Rahul  100000
# 2  E03    Sahil  150000
# 3  E04  Bhushan   45000
# 4  E05  Abhijit  100000
# 5  E06    Viraj  160000
